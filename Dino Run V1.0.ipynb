# %%
#Proposta da Pesquisa

# %% [markdown]
# A proposta deste trabalho visa implementar uma solução em Phyton utilizando técnicas de Algoritmos Genéticos para treinar o jogo Dino Run do Google (O jogo do Dinossauro que aparece no Google Chrome quando e perdido a conexão com a internet). No caso do Dino Run existem três possíveis ações (Agachar, Pular e Não fazer nada). Pretende-se criar uma função para cada ação, justamente para que indique o quão boa essa ação é. Por exemplo: se, em um determinado momento, o jogador deve pular, o valor da ação pular será maior que o valor de agachar ou não fazer nada. Assim, a função de decisão não retornará um número, mas sim um vetor com três números (um para cada ação). Portanto, cada ação terá o seu próprio valor, sem limitações. Será escolhida a ação cuja função dê a maior saída dentre as três.

# %%
#Cromossomo e indivíduo

# %%
import numpy as np

def crossover(individuo1, individuo2):
    """
    Argumentos da Função:
        individuoX: matriz 3x10 com os pesos do individuoX.
    Saída:
        Um novo indivíduo com pesos que podem vir do `individuo1`
        (com chance 1-CHANCE_CO) ou do `individuo2` (com chance CHANCE_CO),
        ou seja, é um cruzamento entre os dois indivíduos. o chance CHANCE_CO,
        copia os respectivos pesos do `individuo2`.
    """
    filho = individuo1.copy()
    for i in range(3):
        for j in range(10):
            if np.random.uniform(0, 1) < CHANCE_CO:
                filho[i][j] = individuo2[i][j]
    return filho

# %%
def calcular_fitness(jogo, individuo):
    """
    Argumentos da Função:
        jogo: objeto que representa o jogo.
        individuo: matriz 3x10 com os pesos do individuo.
    Saída:
        O fitness calculado de um indivíduo. Esse cálculo é feito simulando um
        jogo e calculando o fitness com base nessa simulação. O modo mais simples
        é usando fitness = score do jogo.
    """
    jogo.reset()
    while not jogo.game_over:
        estado = jogo.get_state()
        acao = melhor_jogada(individuo, estado)
        jogo.step(acao)
    return jogo.get_score()
